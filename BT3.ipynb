# %%
#W3A2

a,b=map(int,input().split())

print("Truoc: a =", a, ", b =", b)

a = a ^ b
b = a ^ b
a = a ^ b

print("Sau: a =", a, ", b =", b)
# Out:
#  1 2
# Truoc: a = 1 , b = 2
# Sau: a = 2 , b = 1

# %%
#W3A3
n=int(input())
if n & (n-1) == 0:
    print("Luy thua cua 2")
else:
    print("Khong phai luy thua cua 2")
# Out:
#  10
# Khong phai luy thua cua 2

# %%
#W3A4
m,n=map(float,input().split())
print(int(m/n))
# Out:
#  1 2
# 0

# %%
#W3A5
m,n=map(float,input().split())
print(int(m/n)+1)
# Out:
#  1 2
# 1

# %%
#W3A6
a=int(input("Nhap so nguyen duong: "))
if a%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Nhap so nguyen duong:  10
# Even

# %%
#W3A7
a,b=map(int,input().split())
if a<0 and b<0:
    print("Yes")
else:
    print("No")
# Out:
#  -1 -2
# Yes

# %%
#W3A8
a,b=map(str,input().split())
if a>b:
    print("True")
elif a<=b:
    print("False")
# Out:
#  awdawdawd awdawd
# True

# %%
#W3A8
if len(input("a: ")) > len(input("b: ")):
    print("True")
else:
    print("False")
# Out:
# a:  awdawdawd
# b:  awdawd
# True

# %%
#W3A9
a,b,c = map(int, input().split())
if a > 0 and b > 0 and c > 0 and a + b > c and a + c > b and b + c > a:
    print("Yes")
else:
    print("No")
# Out:
#  2 3 4
# Yes

# %%
#W3A10
a,b,c,d = map(int, input().split())
gtln =a if a>b and a>c and a>d else b if b>c and b>d else c if c>d else d
print(gtln)
# Out:
#  1 2 3 4
# 4

# %%
#W3A11
a,b,c = map(int, input().split())
if a > 0 and b > 0 and c > 0 and a + b > c and a + c > b and b + c > a:
    if a==b==c:
      print("Tam giac deu")
    elif a==b or b==c or a==c:
      print("Tam giac can")
    elif a**2==b**2 + c**2 or b**2==a**2 + c**2 or c**2==b**2 + a**2:
      print("Tam giac vuong")
    else:
      print("Tam giac thuong")
else:
    print("Khong la ba canh cua mot tam giac")
# Out:
#  2 3 4
# Tam giac thuong

# %%
#W3A12
nam = int(input("Nhập năm: "))
if (nam % 400 == 0) or (nam % 4 == 0 and nam % 100 != 0):
    print("Yes")
else:
    print("No")
# Out:
# Nhập năm:  2025
# No

# %%
#W3A14
a,b = map(float, input().split())
if a!=0:
    if b!=0:
        print("Co 1 nghiem x= ",f'{-b/a:.2f}')
    else:
        print("Co 1 nghiem x= 0")
else:
    if b!=0:
        print("Vo nghiem")
    else:
        print("Vo so nghiem")
# Out:
#  1 2
# Co 1 nghiem x=  -2.00

# %%
#W3A15
diem = float(input("Nhập điểm: "))
if diem >= 8:
    print("Giỏi")
elif diem >= 6.5:
    print("Khá")
elif diem >= 5:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Nhập điểm:  10
# Giỏi

# %%
#W3A16
a=float(input())
print(int(a)+1,int(a),round(a))
# Out:
#  9.9
# 10 9 10

# %%
#W3A17
a,b,c,d = map(int, input().split())
if b%a==0 and c%b==0 and d%c==0:
    if a*c==b**2 and b*d==c**2:
        print("Day la CSN co cong boi nguyen")
    else:
        print("Khong phai CSN")
else:
    print("Cong boi khong nguyen")
# Out:
#  1 2 4 8
# Day la CSN co cong boi nguyen

# %%
#W3A17
a,b,c,d = map(int, input().split())
if b % a == 0:             
    q = b // a             
    if b * q == c and c * q == d:
        print("Day la CSN co cong boi nguyen")
    else:
        print("Khong phai CSN")
else:
    print("Cong boi khong nguyen")
# Out:
#  1 2 4 8
# Day la CSN co cong boi nguyen
