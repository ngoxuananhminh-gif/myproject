# %%
#Bai 1
n=int(input("nhap so nguyen n:"))
print (n*2)
# Out:
# nhap so nguyen n: 12
# 24

# %%
#Bai 2
a, b = map(float, input().split())
S= a*b-a/2**2*3.14
print(f'{S:.2f}')
# Out:
#  1 10
# 9.21

# %%
#Bai 3
c = input("Nhập một kí tự: ")
if 'A' <= c <= 'Z':   
    print("Chữ thường:", chr(ord(c) + 32))
elif 'a' <= c <= 'z': 
    print("Chữ hoa:", chr(ord(c) - 32))
else:
    print("Không phải chữ cái, không đổi được.")
# Out:
# Nhập một kí tự:  a
# Chữ hoa: A

# %%
#Bai 4
c = input("Nhập một kí tự: ")
if ('A' <= c <= 'Z') or ('a' <= c <= 'z'):
    print(f"'{c}' là kí tự alphabet")
else:
    print(f"'{c}' không phải là kí tự alphabet")
# Out:
# Nhập một kí tự:  a
# 'a' là kí tự alphabet

# %%
#Bai 5
c = input("Nhập một kí tự: ")
print(chr(ord(c) + 31))
# Out:
# Nhập một kí tự:  B
# a

# %%
#Bai 6
import math
a,b,c = map(float, input().split())
d=(a+b+c)/2
if a > 0 and b > 0 and c > 0 and a + b > c and a + c > b and b + c > a:
    S = math.sqrt(d * (d - a) * (d - b) * (d - c))
    print(f"Diện tích tam giác: {S:.1f}")
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
#  2 3 4
# Diện tích tam giác: 2.9

# %%
#Bai 7
s = input()
if len(s) >= 20:
    print("Ký tự thứ 5:", s[4])   
    print("Ký tự thứ 9:", s[8])
# Out:
#  waweweigwiygeiygwigecwi
# Ký tự thứ 5: w
# Ký tự thứ 9: w

# %%
#Bai 8
a=input("Ten chu ho:")
b=int(input("Chi so thang truoc:"))
c=int(input("Chi so thang nay:")) 

d=c-b
import math
def e(d):
    if 0<= d <= 50:
        tien = d*1984
    elif 51<= d <= 100:
        tien = d*2050
    elif 101<= d <= 200:
        tien = d*2380
    elif 201<= d <= 300:
        tien = d*2998
    elif 301<= d <= 400:
        tien = d*3350
    else:
        tien = d*3460
    return tien

tiendien = e(d)
tongtien = int(round(tiendien * 1.08))  

# In kết quả
print("Ho va ten:", ten)
print("Tien phai tra la:", tongtien)
# Out:
# Ten chu ho: www
# Chi so thang truoc: 1020
# Chi so thang nay: 1070
# Ho va ten: www
# Tien phai tra la: 107136

# %%
#1
n = int(input("Nhập số nguyên: "))
if n % 2 == 0:
    print("Số chẵn")
else:
    print("Số lẻ")
# Out:
# Nhập số nguyên:  2
# Số chẵn

# %%
#2
n = int(input("Nhập số nguyên: "))
if n % 10 == 5:
    print("True")
else:
    print("False")
# Out:
# Nhập số nguyên:  2
# False

# %%
#3
n = int(input("Nhập số nguyên: "))
if n % 3 == 0 and n % 5 == 0:
    print("True")
else:
    print("False")
# Out:
# Nhập số nguyên:  2
# False

# %%
#4
a = int(input("Nhập năm sinh: "))
tuoi = 2025 - a
if tuoi >= 18:
    print("Đủ tuổi đi bầu cử")
else:
    print("Chưa đủ tuổi đi bầu cử")
# Out:
# Nhập năm sinh:  2007
# Đủ tuổi đi bầu cử

# %%
#5
a = float(input("Nhập số thứ nhất: "))
b = float(input("Nhập số thứ hai: "))

if a > b:
    print("Số lớn hơn là:", a)
elif a < b:
    print("Số lớn hơn là:", b)
else:
    print("Hai số bằng nhau")
# Out:
# Nhập số thứ nhất:  2
# Nhập số thứ hai:  2
# Hai số bằng nhau

# %%
#6
c = input("Nhập một ký tự: ")

if 'A' <= c <= 'Z' or 'a' <= c <= 'z':
    print("Đây là chữ cái")
elif '0' <= c <= '9':
    print("Đây là chữ số")
else:
    print("Không phải chữ cũng không phải số")
# Out:
# Nhập một ký tự:  2
# Đây là chữ số

# %%
#7
diem = float(input("Nhập điểm: "))

if diem >= 8:
    print("Giỏi")
elif diem >= 6.5:
    print("Khá")
elif diem >= 5:
    print("Trung bình")
else:
    print("Yếu")
# Out:
# Nhập điểm:  10
# Giỏi

# %%
#8
nam = int(input("Nhập năm: "))
if (nam % 400 == 0) or (nam % 4 == 0 and nam % 100 != 0):
    print("Năm nhuận")
else:
    print("Không phải năm nhuận")
# Out:
# Nhập năm:  2025
# Không phải năm nhuận

# %%
#9
n = int(input("Nhập số từ 0 đến 9: "))

match n:
    case 0: print("Không")
    case 1: print("Một")
    case 2: print("Hai")
    case 3: print("Ba")
    case 4: print("Bốn")
    case 5: print("Năm")
    case 6: print("Sáu")
    case 7: print("Bảy")
    case 8: print("Tám")
    case 9: print("Chín")
# Out:
# Nhập số từ 0 đến 9:  9
# Chín

# %%
#10
diem = float(input("Nhập điểm thi: "))
if diem >= 4:
    print("Qua môn")
else:
    print("Học lại")
# Out:
# Nhập điểm thi:  10
# Qua môn

# %%
#11
a = int(input("Nhập năm sinh: "))
tuoi = 2025 - a
print("Tuổi hiện tại:", tuoi)

if tuoi >= 18:
    print("Đủ 18 tuổi")
else:
    print("Chưa đủ 18 tuổi")
# Out:
# Nhập năm sinh:  2007
# Tuổi hiện tại: 18
# Đủ 18 tuổi
